# %%
# imports
#!pip install openai
#!pip install tiktoken # for counting tokens answer_rater needs that
#!pip install python-dotenv


import openai  # for generating embeddings
import pandas as pd  # for DataFrames to store article sections and embeddings
import numpy as np
from dotenv import dotenv_values
from answer_rater import rank_answer # you can find it from main dir

# %%
#To use embeddings you must create an .env file where the content is OPENAI_API_KEY = "your-api-key"
config = dotenv_values(".env")["OPENAI_API_KEY"]
openai.organization = "org-3O7bHGD9SwjHVDuUCNCGACC3"
openai.api_key = config

# %%
# Read the CSV file into a Pandas DataFrame
df = pd.read_csv('qa.csv')

# Add evaluation column for each model
models = ['Law-Aware AI bot', 'GPT-3.5', 'GPT-4']
for model in models:
    df[model + ' eval.'] = ''

# %%
df
# Out:
#                                              Question  \
# 0                    How does a minister take office?
# 1   What are the primary obligations of the landlo...
# 2   What kind of financial support is available to...
# 3   What is the process of formalizing a divorce i...
# 4   Under what conditions can an employment contra...
# 5        What is the legal age of consent in Estonia?
# 6   What are the rights and obligations of the ten...
# 7   What are the requirements for establishing a l...
# 8   What legal rights do I have as a consumer in E...
# 9   Can you provide details about the digital citi...
# 10  What are the primary data protection regulatio...
# 11  How is custody of a child determined in Estoni...
# 12  What support is it possible to get for startup...
# 13          What are the inheritance laws in Estonia?
# 14  What are the penalties for drunk driving in Es...
# 15      What laws apply to parental leave in Estonia?
# ...

# %%
# Iterate over the DataFrame rows
for index, row in df[0:].iterrows():
    question = row['Question']
    print(index)
    print(question)
    # Iterate over each model
    for model in models:
        answer = row[model]
        answer = answer.replace('\n\n', '')  # Remove newline characters
        print(answer)
        # Uncomment and money goes and results comes
        #df.at[index, model + ' eval.'] = rank_answer(answer, question, openai, model='gpt-3.5-turbo',ftf_answer='Did not find an answer to the question in the law, try to rephrase the question.')

# %%
df
# Out:
#                                              Question  \
# 0                    How does a minister take office?
# 1   What are the primary obligations of the landlo...
# 2   What kind of financial support is available to...
# 3   What is the process of formalizing a divorce i...
# 4   Under what conditions can an employment contra...
# 5        What is the legal age of consent in Estonia?
# 6   What are the rights and obligations of the ten...
# 7   What are the requirements for establishing a l...
# 8   What legal rights do I have as a consumer in E...
# 9   Can you provide details about the digital citi...
# 10  What are the primary data protection regulatio...
# 11  How is custody of a child determined in Estoni...
# 12  What support is it possible to get for startup...
# 13          What are the inheritance laws in Estonia?
# 14  What are the penalties for drunk driving in Es...
# 15      What laws apply to parental leave in Estonia?
# ...

# %%
# Save the updated DataFrame to a new CSV file
df.to_csv('qae.csv', index=False)

# %%
df[['Law-Aware AI bot eval.', 'GPT-3.5 eval.', 'GPT-4 eval.']]
# Out:
#                                Law-Aware AI bot eval.  \
# 0   Hinnang vastusele: Accuracy: 10/10\nDepth: 6/1...
# 1   Hinnang vastusele: Accuracy: 10/10\nDepth: 7/1...
# 2   Hinnang vastusele: Accuracy: 10/10\nDepth: 7/1...
# 3                                Hinnang vastusele: -
# 4   Hinnang vastusele: Accuracy: 10/10 - The state...
# 5                                Hinnang vastusele: -
# 6   Hinnang vastusele: Accuracy: 9/10 - The statem...
# 7                                Hinnang vastusele: -
# 8   Hinnang vastusele: Accuracy: 10\nDepth: 8\nCla...
# 9                                Hinnang vastusele: -
# 10                               Hinnang vastusele: -
# 11                               Hinnang vastusele: -
# 12                               Hinnang vastusele: -
# 13  Hinnang vastusele: Accuracy: 10/10\nDepth: 8/1...
# 14  Hinnang vastusele: Accuracy: 10/10 - The state...
# 15  Hinnang vastusele: Accuracy: 10/10\nDepth: 7/1...
# ...
